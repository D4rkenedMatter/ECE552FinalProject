# %%
# %run ../ImportsConstantsSparkStartup.ipynb
sc.setJobGroup("PLT_DayOfWeek", "PLT_DayOfWeek")

# %%
pipeline = "[{$set:{'DayOfWeek':{$toString:'$DayOfWeek'}}}{$sort:{'DayOfWeek':1}}]"
df = spark.read.format("mongo").option("collection", "AccidentCountByDayOfWeek").option("pipeline", pipeline).load()
df.printSchema()
# Out:
# root
#  |-- AccidentCount: long (nullable = true)
#  |-- DayOfWeek: string (nullable = true)
#  |-- _id: struct (nullable = true)
#  |    |-- oid: string (nullable = true)

# %%
df = df.na.replace(daysDict)
df.show()
df = df.toPandas()
# Out:
# +-------------+---------+--------------------+
# |AccidentCount|DayOfWeek|                 _id|
# +-------------+---------+--------------------+
# |       268985|   Sunday|[646009dd5d64100a...|
# |       416218|   Monday|[646009dd5d64100a...|
# |       442743|  Tuesday|[646009dd5d64100a...|
# |       451940|Wednesday|[646009dd5d64100a...|
# |       461044| Thursday|[646009dd5d64100a...|
# |       484472|   Friday|[646009dd5d64100a...|
# |       319940| Saturday|[646009dd5d64100a...|
# +-------------+---------+--------------------+

# %%
df = df.set_index('DayOfWeek')
display(df)
# Out:
#            AccidentCount                          _id
# DayOfWeek
# Sunday            268985  (646009dd5d64100a8ae33d18,)
# Monday            416218  (646009dd5d64100a8ae33d17,)
# Tuesday           442743  (646009dd5d64100a8ae33d1a,)
# Wednesday         451940  (646009dd5d64100a8ae33d1b,)
# Thursday          461044  (646009dd5d64100a8ae33d1c,)
# Friday            484472  (646009dd5d64100a8ae33d16,)
# Saturday          319940  (646009dd5d64100a8ae33d19,)

# %%
ax = df.plot.bar(rot=45, legend=False, figsize=(10,10))
ax.set_xlabel("Day of Week", fontsize=20)
ax.set_ylabel("Accident Count", fontsize=20)
ax.set_title("Accident Count By Day of Week", fontsize = 25)
ax.grid(color='grey', linestyle='dashed', linewidth=1, axis='y')
ax.yaxis.set_major_formatter(StrMethodFormatter('{x:,}'))
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
